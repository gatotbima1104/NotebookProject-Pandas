# %%
import pandas as pd
import numpy as np

# %%
excel = pd.read_csv("heart_2020_cleaned.csv")
excel
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
dt = excel.corr()
dt.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_34b74_row0_col0, #T_34b74_row1_col1, #T_34b74_row2_col2, #T_34b74_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_34b74_row0_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_34b74_row0_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_34b74_row0_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_34b74_row1_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_34b74_row1_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_34b74_row1_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_34b74_row2_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_34b74_row2_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_34b74_row2_col3, #T_34b74_row3_col0, #T_34b74_row3_col1, #T_34b74_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_34b74">
#   <thead>
#     <tr>
# ...

# %%
x = excel.drop(["HeartDisease","Smoking","AlcoholDrinking","Stroke","DiffWalking",
                "Sex","AgeCategory","Race","Diabetic","PhysicalActivity","GenHealth","Asthma",
                "KidneyDisease","SkinCancer"], axis=1)
x.head(5)

##jvkhbjk
# Out:
#      BMI  PhysicalHealth  MentalHealth  SleepTime
# 0  16.60             3.0          30.0        5.0
# 1  20.34             0.0           0.0        7.0
# 2  26.58            20.0          30.0        8.0
# 3  24.21             0.0           0.0        6.0
# 4  23.71            28.0           0.0        8.0

# %%
y = excel['HeartDisease']

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
nbc = GaussianNB()

# %%
data_training = nbc.fit(x_train, y_train)

# %%
y_predict = data_training.predict(x_test)
print(y_predict)
# Out:
# ['No' 'No' 'No' ... 'No' 'No' 'No']

# %%
## Example people
BMI = 27.41
PhysicalHealth = 7.0
MentalHealth = 0.0
SleepTime = 6.0

##testing
Data_Testing = [[BMI,PhysicalHealth,MentalHealth,SleepTime]]

# %%
y_pred = data_training.predict(Data_Testing)
# Out:
# C:\Users\Muhamad\miniconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
if y_pred == 'No':
    hasil = "Tidak terkena"
elif y_pred == 'Yes':
    hasil = "Akan terkena"
else:
    hasil = "eror"
    
print("Resiko Terkena Penyakit Jantung =",hasil)
# Out:
# Resiko Terkena Penyakit Jantung = Tidak terkena

# %%
from sklearn.metrics import accuracy_score
print("nilai akurasi = %0.2f " % accuracy_score(y_test,y_predict))
# Out:
# nilai akurasi = 0.85

# %%
score = accuracy_score(y_test, y_predict)
print ('Nilai akurasi :', float(score))
# Out:
# Nilai akurasi : 0.8497162244562924

# %%
from sklearn.metrics import classification_report
print(classification_report(y,y_predict))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 2>()
#       1 from sklearn.metrics import classification_report
# ----> 2 print(classification_report(y,y_predict))
#
# File ~\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:2125, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2010 def classification_report(
#    2011     y_true,
#    2012     y_pred,
#    (...)
#    2019     zero_division="warn",
#    2020 ):
#    2021     """Build a text report showing the main classification metrics.
#    2022
#    2023     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2122     <BLANKLINE>
#    2123     """
# -> 2125     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2127     if labels is None:
# ...
